# %%
from HeaderP import *
from bokeh.io import curdoc
from bokeh.layouts import column, row
from bokeh.models import ColumnDataSource, Div, Select, Slider, TextInput
from bokeh.plotting import figure
# %matplotlib inline
from bokeh.io import output_notebook, show, push_notebook
from bokeh.plotting import figure, output_file
from ipywidgets import interact
import random
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
APOGEE=pd.read_pickle('/Users/yl4331/Desktop/SecondYear_2/Data/APOGEE.pkl')[['RA','DEC']]
GALAH=pd.read_pickle('/Users/yl4331/Desktop/SecondYear_2/Data/galah_gaia_cm.pkl')[['ra_x','dec_x']]
Kepler_prot=pd.read_pickle('/Users/yl4331/Desktop/SecondYear_2/Data/Mc_Gar_Sant')[['ra','dec']]

# %%
RAVE=pd.read_csv('/Users/yl4331/Desktop/SecondYear_2/Data/ravedr6.csv')[['ra','dec']]

# %%
LAMOST=pd.read_csv('/Users/yl4331/Desktop/SecondYear_2/Data/dr6_v2_LRS.csv',delimiter='|')
# Out:
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (30) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
APOGEE['survey']='APOGEE'
APOGEE['ra']=APOGEE['RA']
APOGEE['dec']=APOGEE['DEC']
APOGEE['color']='red'
APOGEE['dtypes']='spectra'


GALAH['survey']='GALAH'
GALAH['ra']=GALAH['ra_x']
GALAH['dec']=GALAH['dec_x']
GALAH['color']='black'
GALAH['dtypes']='spectra'

Kepler_prot['survey']='Kepler'
Kepler_prot['color']='blue'
Kepler_prot['dtypes']='Prot, lightcurves'

# %%
joinsurv=pd.concat([APOGEE,GALAH,Kepler_prot])[['survey','ra','dec','color','dtypes']]

# %%
joinsurv
# Out:
#        survey          ra        dec color             dtypes
# 1      APOGEE    0.000103  74.285408   red            spectra
# 2      APOGEE    0.000832 -19.413851   red            spectra
# 3      APOGEE    0.001335  57.619530   red            spectra
# 4      APOGEE    0.001335  57.619530   red            spectra
# 5      APOGEE    0.002850  57.173164   red            spectra
# ...       ...         ...        ...   ...                ...
# 38568  Kepler  290.435721  52.178068  blue  Prot, lightcurves
# 38569  Kepler  289.597971  52.229048  blue  Prot, lightcurves
# 38570  Kepler  289.728559  52.207544  blue  Prot, lightcurves
# 38571  Kepler  290.199203  52.249039  blue  Prot, lightcurves
# 38572  Kepler  290.155423  52.386018  blue  Prot, lightcurves
#
# [1089241 rows x 5 columns]

# %%
plt.figure(figsize=(10,8))
plt.scatter(joinsurv['ra'],joinsurv['dec'],color=joinsurv['color'],s=1,alpha=0.5)
plt.xlabel('RA')
plt.ylabel('Dec')
# Out:
# Text(0, 0.5, 'Dec')
